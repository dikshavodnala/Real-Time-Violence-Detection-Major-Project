# %%
import tensorflow as tf
from tensorflow import keras
print("GPUs:",len(tf.config.experimental.list_physical_devices('GPU')))
tf.test.is_built_with_cuda()
# Out:
# GPUs: 1
# True

# %%
print(tf.version.VERSION)
import sys
sys.version
# Out:
# 2.10.1
# '3.10.16 | packaged by Anaconda, Inc. | (main, Dec 11 2024, 16:19:12) [MSC v.1929 64 bit (AMD64)]'

# %%
# !pip install opencv-python
# !pip install matplotlib
# !pip install scikit-learn
# Out:
# Requirement already satisfied: opencv-python in c:\users\student\.conda\envs\py310\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\student\.conda\envs\py310\lib\site-packages (from opencv-python) (1.23.5)
# Requirement already satisfied: matplotlib in c:\users\student\.conda\envs\py310\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\student\.conda\envs\py310\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\student\.conda\envs\py310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\student\.conda\envs\py310\lib\site-packages (from matplotlib) (4.55.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\student\.conda\envs\py310\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\student\.conda\envs\py310\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\student\.conda\envs\py310\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\student\.conda\envs\py310\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\student\.conda\envs\py310\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\student\.conda\envs\py310\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\student\.conda\envs\py310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: scikit-learn in c:\users\student\.conda\envs\py310\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\student\.conda\envs\py310\lib\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\student\.conda\envs\py310\lib\site-packages (from scikit-learn) (1.15.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\student\.conda\envs\py310\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\student\.conda\envs\py310\lib\site-packages (from scikit-learn) (3.5.0)

# %%
import os
import shutil
import cv2
import math
import random
import numpy as np
import datetime as dt
import tensorflow 
import keras
from collections import deque
import matplotlib.pyplot as plt


# %matplotlib inline
 
from sklearn.model_selection import train_test_split
 
from keras.layers import *
from keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\.conda\envs\py310\lib\site-packages\matplotlib\style\core.py:129, in use(style)
#     128 try:
# --> 129     style = _rc_params_in_file(style)
#     130 except OSError as err:
#
# File ~\.conda\envs\py310\lib\site-packages\matplotlib\__init__.py:903, in _rc_params_in_file(fname, transform, fail_on_error)
#     902 rc_temp = {}
# --> 903 with _open_file_or_url(fname) as fd:
#     904     try:
#
# File ~\.conda\envs\py310\lib\contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#
# File ~\.conda\envs\py310\lib\site-packages\matplotlib\__init__.py:880, in _open_file_or_url(fname)
#     879 fname = os.path.expanduser(fname)
# --> 880 with open(fname, encoding='utf-8') as f:
#     881     yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'seaborn'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[65], line 12
#      10 from collections import deque
#      11 import matplotlib.pyplot as plt
# ---> 12 plt.style.use("seaborn")
#      14 get_ipython().run_line_magic('matplotlib', 'inline')
#      16 from sklearn.model_selection import train_test_split
#
# File ~\.conda\envs\py310\lib\site-packages\matplotlib\style\core.py:131, in use(style)
#     129         style = _rc_params_in_file(style)
#     130     except OSError as err:
# --> 131         raise OSError(
#     132             f"{style!r} is not a valid package style, path of style "
#     133             f"file, URL of style file, or library style name (library "
#     134             f"styles are listed in `style.available`)") from err
#     135 filtered = {}
#     136 for k in style:  # don't trigger RcParams.__getitem__('backend')
#
# OSError: 'seaborn' is not a valid package style, path of style file, URL of style file, or library style name (library styles are listed in `style.available`)

# %%
# Specify the height and width to which each video frame will be resized in our dataset.
IMAGE_HEIGHT , IMAGE_WIDTH = 64, 64
 
# Specify the number of frames of a video that will be fed to the model as one sequence.
SEQUENCE_LENGTH = 16
 
dataset_dir = os.path.expanduser("D:/21102A0004/data")
 
CLASSES_LIST = ["crime","non-crime"]

# Verify if the dataset directory exists
if not os.path.exists(dataset_dir):
    print(f"Dataset directory does not exist: {dataset_dir}")
else:
    print(f"Dataset directory exists: {dataset_dir}")
# Out:
# Dataset directory exists: D:/21102A0004/data

# %%
def frames_extraction(video_path):
 
    frames_list = []
    
    # Read the Video File
    video_reader = cv2.VideoCapture(video_path)
 
    # Get the total number of frames in the video.
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
 
    # Calculate the the interval after which frames will be added to the list.
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)
 
    # Iterate through the Video Frames.
    for frame_counter in range(SEQUENCE_LENGTH):
 
        # Set the current frame position of the video.
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)
 
        # Reading the frame from the video. 
        success, frame = video_reader.read() 
 
        if not success:
            break
 
        # Resize the Frame to fixed height and width.
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))
        
        # Normalize the resized frame
        normalized_frame = resized_frame / 255
        
        # Append the normalized frame into the frames list
        frames_list.append(normalized_frame)
    
 
    video_reader.release()
 
    return frames_list

# %%
def create_dataset():
 
    features = []
    labels = []
    video_files_paths = []
    
    # Iterating through all the classes.
    for class_index, class_name in enumerate(CLASSES_LIST):
        
        print(f'Extracting Data of Class: {class_name}')
        
        # Get the list of video files present in the specific class name directory.
        files_list = os.listdir(os.path.join(dataset_dir, class_name))
        
        # Iterate through all the files present in the files list.
        for file_name in files_list:
            
            # Get the complete video path.
            video_file_path = os.path.join(dataset_dir, class_name, file_name)
 
            # Extract the frames of the video file.
            frames = frames_extraction(video_file_path)
 
            # Check if the extracted frames are equal to the SEQUENCE_LENGTH specified.
            # So ignore the vides having frames less than the SEQUENCE_LENGTH.
            if len(frames) == SEQUENCE_LENGTH:
 
                # Append the data to their repective lists.
                features.append(frames)
                labels.append(class_index)
                video_files_paths.append(video_file_path)
 
    features = np.asarray(features)
    labels = np.array(labels)  

    return features, labels, video_files_paths

# %%
# Create the dataset.
features, labels, video_files_paths = create_dataset()
# Out:
# Extracting Data of Class: crime
# Extracting Data of Class: non-crime

# %%
# Saving the extracted data
np.save("features.npy",features)
np.save("labels.npy",labels)
np.save("video_files_paths.npy",video_files_paths)

# %%
features, labels, video_files_paths = np.load("features.npy") , np.load("labels.npy") ,  np.load("video_files_paths.npy")

# %%
# convert labels into one-hot-encoded vectors
one_hot_encoded_labels = to_categorical(labels)

# %%
# Split the Data into Train ( 90% ) and Test Set ( 10% ).
features_train, features_test, labels_train, labels_test = train_test_split(features, one_hot_encoded_labels, test_size = 0.2,
                                                                            shuffle = True, random_state = 42)

# %%
print(features_train.shape,labels_train.shape )
print(features_test.shape, labels_test.shape)
# Out:
# (2171, 16, 64, 64, 3) (2171, 2)
# (543, 16, 64, 64, 3) (543, 2)

# %% [markdown]
# ## ConvLSTM Model

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import BatchNormalization, GlobalAveragePooling3D

def create_convlstm_model():
  model = Sequential()

  model.add(ConvLSTM2D(filters=32,kernel_size=(3,3),activation='relu',data_format="channels_last",
                       recurrent_dropout=0.1,return_sequences=True, input_shape = (SEQUENCE_LENGTH,
                                                                                      IMAGE_HEIGHT, IMAGE_WIDTH, 3)))
  model.add(BatchNormalization())
  model.add(MaxPooling3D(pool_size=(1,2,2),padding='same',data_format='channels_last'))
  model.add(TimeDistributed(Dropout(0.3)))

  model.add(ConvLSTM2D(filters = 64, kernel_size = (3, 3), activation = 'relu', data_format = "channels_last",
                         recurrent_dropout=0.1, return_sequences=True))

  model.add(BatchNormalization())
  model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
  model.add(TimeDistributed(Dropout(0.3)))

  model.add(ConvLSTM2D(filters = 128, kernel_size = (3, 3), activation = 'relu', data_format = "channels_last",
                         recurrent_dropout=0.1, return_sequences=True))

  model.add(BatchNormalization())
  model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
  model.add(TimeDistributed(Dropout(0.3)))

  model.add(ConvLSTM2D(filters = 256, kernel_size = (3, 3), activation = 'relu', data_format = "channels_last",
                         recurrent_dropout=0.1, return_sequences=True))

  model.add(BatchNormalization())
  model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
  model.add(TimeDistributed(Dropout(0.4)))

    # model.add(Flatten())
  model.add(GlobalAveragePooling3D())

    # Dense Layers
  model.add(Dense(256, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(len(CLASSES_LIST), activation="sigmoid"))

    # Display the model summary
  model.summary()

    # Compile the model
    # Return the constructed convlstm model.
  return model

# %%
# Construct the required convlstm model.
convlstm_model = create_convlstm_model()

# Display the success message.
print("Model Created Successfully!")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_lstm2d (ConvLSTM2D)    (None, 16, 62, 62, 32)    40448
#
#  batch_normalization (BatchN  (None, 16, 62, 62, 32)   128
#  ormalization)
#
#  max_pooling3d (MaxPooling3D  (None, 16, 31, 31, 32)   0
#  )
#
#  time_distributed (TimeDistr  (None, 16, 31, 31, 32)   0
#  ibuted)
#
#  conv_lstm2d_1 (ConvLSTM2D)  (None, 16, 29, 29, 64)    221440
#
#  batch_normalization_1 (Batc  (None, 16, 29, 29, 64)   256
#  hNormalization)
#
#  max_pooling3d_1 (MaxPooling  (None, 16, 15, 15, 64)   0
#  3D)
#
#  time_distributed_1 (TimeDis  (None, 16, 15, 15, 64)   0
#  tributed)
#
#  conv_lstm2d_2 (ConvLSTM2D)  (None, 16, 13, 13, 128)   885248
#
#  batch_normalization_2 (Batc  (None, 16, 13, 13, 128)  512
#  hNormalization)
#
#  max_pooling3d_2 (MaxPooling  (None, 16, 7, 7, 128)    0
#  3D)
#
#  time_distributed_2 (TimeDis  (None, 16, 7, 7, 128)    0
#  tributed)
#
#  conv_lstm2d_3 (ConvLSTM2D)  (None, 16, 5, 5, 256)     3539968
#
#  batch_normalization_3 (Batc  (None, 16, 5, 5, 256)    1024
#  hNormalization)
#
#  max_pooling3d_3 (MaxPooling  (None, 16, 3, 3, 256)    0
#  3D)
#
#  time_distributed_3 (TimeDis  (None, 16, 3, 3, 256)    0
#  tributed)
#
#  global_average_pooling3d (G  (None, 256)              0
#  lobalAveragePooling3D)
#
#  dense (Dense)               (None, 256)               65792
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 4,755,330
# Trainable params: 4,754,370
# Non-trainable params: 960
# _________________________________________________________________
# Model Created Successfully!

# %%
# !pip install pydot
# Out:
# Requirement already satisfied: pydot in c:\users\student\.conda\envs\py310\lib\site-packages (3.0.4)
# Requirement already satisfied: pyparsing>=3.0.9 in c:\users\student\.conda\envs\py310\lib\site-packages (from pydot) (3.2.1)

# %%
# Plot the structure of the contructed model.
plot_model(convlstm_model, to_file = 'convlstm_model_structure_plot.png', show_shapes = True, show_layer_names = True)

# %%
# Create an Instance of Early Stopping Callback
early_stopping_callback = EarlyStopping(monitor='val_accuracy',patience=20,mode='max',restore_best_weights = True)

# Compile the model and specify loss function, optimizer and metrics values to the model
convlstm_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Start training the model.
convlstm_model_training_history = convlstm_model.fit(x = features_train, y = labels_train, epochs = 70, batch_size = 4,
                                                      shuffle = True, validation_split = 0.2,
                                                     callbacks = [early_stopping_callback])
# Out:
# Epoch 1/70
# 434/434 [==============================] - 110s 230ms/step - loss: 0.7004 - accuracy: 0.5156 - val_loss: 0.6909 - val_accuracy: 0.5425
# Epoch 2/70
# 434/434 [==============================] - 105s 243ms/step - loss: 0.6703 - accuracy: 0.6014 - val_loss: 0.6950 - val_accuracy: 0.5425
# Epoch 3/70
# 434/434 [==============================] - 99s 227ms/step - loss: 0.6782 - accuracy: 0.5691 - val_loss: 0.6961 - val_accuracy: 0.5425
# Epoch 4/70
# 434/434 [==============================] - 98s 226ms/step - loss: 0.6937 - accuracy: 0.5501 - val_loss: 0.7310 - val_accuracy: 0.5425
# Epoch 5/70
# 434/434 [==============================] - 100s 230ms/step - loss: 0.6846 - accuracy: 0.5680 - val_loss: 0.7019 - val_accuracy: 0.5425
# Epoch 6/70
# 434/434 [==============================] - 96s 220ms/step - loss: 0.6635 - accuracy: 0.5933 - val_loss: 0.6909 - val_accuracy: 0.5402
# Epoch 7/70
# 434/434 [==============================] - 100s 230ms/step - loss: 0.6612 - accuracy: 0.6002 - val_loss: 0.6925 - val_accuracy: 0.5425
# Epoch 8/70
# 434/434 [==============================] - 93s 214ms/step - loss: 0.6726 - accuracy: 0.5737 - val_loss: 0.8065 - val_accuracy: 0.5425
# Epoch 9/70
# 434/434 [==============================] - 99s 229ms/step - loss: 0.6792 - accuracy: 0.5737 - val_loss: 0.9782 - val_accuracy: 0.5425
# Epoch 10/70
# 434/434 [==============================] - 96s 220ms/step - loss: 0.6621 - accuracy: 0.6164 - val_loss: 0.7498 - val_accuracy: 0.5425
# Epoch 11/70
# 434/434 [==============================] - 97s 223ms/step - loss: 0.6420 - accuracy: 0.6325 - val_loss: 0.7683 - val_accuracy: 0.5402
# Epoch 12/70
# 434/434 [==============================] - 101s 233ms/step - loss: 0.6478 - accuracy: 0.6181 - val_loss: 0.8685 - val_accuracy: 0.5425
# Epoch 13/70
# 434/434 [==============================] - 93s 213ms/step - loss: 0.6269 - accuracy: 0.6434 - val_loss: 0.9658 - val_accuracy: 0.5425
# Epoch 14/70
# 434/434 [==============================] - 99s 228ms/step - loss: 0.6249 - accuracy: 0.6509 - val_loss: 1.0185 - val_accuracy: 0.5425
# Epoch 15/70
# 434/434 [==============================] - 105s 241ms/step - loss: 0.6239 - accuracy: 0.6550 - val_loss: 0.7807 - val_accuracy: 0.5425
# Epoch 16/70
# 434/434 [==============================] - 99s 229ms/step - loss: 0.6232 - accuracy: 0.6532 - val_loss: 0.7523 - val_accuracy: 0.5425
# Epoch 17/70
# 434/434 [==============================] - 101s 233ms/step - loss: 0.6258 - accuracy: 0.6480 - val_loss: 0.9510 - val_accuracy: 0.5425
# Epoch 18/70
# 434/434 [==============================] - 95s 219ms/step - loss: 0.6085 - accuracy: 0.6843 - val_loss: 0.6724 - val_accuracy: 0.5448
# Epoch 19/70
# 434/434 [==============================] - 97s 224ms/step - loss: 0.6085 - accuracy: 0.6763 - val_loss: 0.6577 - val_accuracy: 0.5609
# Epoch 20/70
# 434/434 [==============================] - 95s 219ms/step - loss: 0.6143 - accuracy: 0.6532 - val_loss: 0.6970 - val_accuracy: 0.5425
# Epoch 21/70
# 434/434 [==============================] - 103s 238ms/step - loss: 0.5966 - accuracy: 0.6797 - val_loss: 0.6492 - val_accuracy: 0.6069
# Epoch 22/70
# 434/434 [==============================] - 102s 235ms/step - loss: 0.6361 - accuracy: 0.6423 - val_loss: 0.7467 - val_accuracy: 0.5425
# Epoch 23/70
# 434/434 [==============================] - 99s 228ms/step - loss: 0.6317 - accuracy: 0.6532 - val_loss: 0.7738 - val_accuracy: 0.5425
# Epoch 24/70
# 434/434 [==============================] - 105s 241ms/step - loss: 0.6328 - accuracy: 0.6400 - val_loss: 0.6880 - val_accuracy: 0.5425
# Epoch 25/70
# 434/434 [==============================] - 101s 233ms/step - loss: 0.6175 - accuracy: 0.6636 - val_loss: 0.6390 - val_accuracy: 0.5977
# Epoch 26/70
# 434/434 [==============================] - 100s 231ms/step - loss: 0.5973 - accuracy: 0.6745 - val_loss: 0.6357 - val_accuracy: 0.6069
# Epoch 27/70
# 434/434 [==============================] - 95s 219ms/step - loss: 0.6214 - accuracy: 0.6544 - val_loss: 0.6609 - val_accuracy: 0.5747
# Epoch 28/70
# 434/434 [==============================] - 99s 228ms/step - loss: 0.6195 - accuracy: 0.6492 - val_loss: 0.6409 - val_accuracy: 0.5908
# Epoch 29/70
# 434/434 [==============================] - 98s 225ms/step - loss: 0.6062 - accuracy: 0.6734 - val_loss: 0.6436 - val_accuracy: 0.5954
# Epoch 30/70
# 434/434 [==============================] - 98s 225ms/step - loss: 0.5969 - accuracy: 0.6901 - val_loss: 0.6003 - val_accuracy: 0.6759
# Epoch 31/70
# 434/434 [==============================] - 98s 226ms/step - loss: 0.5891 - accuracy: 0.6780 - val_loss: 0.6368 - val_accuracy: 0.6046
# Epoch 32/70
# 434/434 [==============================] - 98s 225ms/step - loss: 0.5903 - accuracy: 0.6872 - val_loss: 0.6444 - val_accuracy: 0.5931
# Epoch 33/70
# 434/434 [==============================] - 98s 226ms/step - loss: 0.5877 - accuracy: 0.6878 - val_loss: 0.6399 - val_accuracy: 0.5862
# Epoch 34/70
# 434/434 [==============================] - 97s 222ms/step - loss: 0.5715 - accuracy: 0.6901 - val_loss: 0.6452 - val_accuracy: 0.5977
# Epoch 35/70
# 434/434 [==============================] - 96s 220ms/step - loss: 0.5768 - accuracy: 0.6912 - val_loss: 0.7488 - val_accuracy: 0.5425
# Epoch 36/70
# 434/434 [==============================] - 96s 222ms/step - loss: 0.5760 - accuracy: 0.6815 - val_loss: 0.7426 - val_accuracy: 0.5425
# Epoch 37/70
# 434/434 [==============================] - 102s 235ms/step - loss: 0.5866 - accuracy: 0.6797 - val_loss: 0.6688 - val_accuracy: 0.5747
# Epoch 38/70
# 434/434 [==============================] - 103s 237ms/step - loss: 0.5855 - accuracy: 0.6866 - val_loss: 0.7308 - val_accuracy: 0.5563
# Epoch 39/70
# 434/434 [==============================] - 99s 228ms/step - loss: 0.6023 - accuracy: 0.6694 - val_loss: 0.8173 - val_accuracy: 0.5425
# Epoch 40/70
# 434/434 [==============================] - 99s 229ms/step - loss: 0.5799 - accuracy: 0.6912 - val_loss: 0.8829 - val_accuracy: 0.5425
# Epoch 41/70
# 434/434 [==============================] - 99s 228ms/step - loss: 0.5908 - accuracy: 0.6855 - val_loss: 0.7394 - val_accuracy: 0.5425
# Epoch 42/70
# 434/434 [==============================] - 94s 218ms/step - loss: 0.5737 - accuracy: 0.6976 - val_loss: 0.9998 - val_accuracy: 0.5402
# Epoch 43/70
# 434/434 [==============================] - 98s 227ms/step - loss: 0.5857 - accuracy: 0.6855 - val_loss: 0.8946 - val_accuracy: 0.5425
# Epoch 44/70
# 434/434 [==============================] - 95s 219ms/step - loss: 0.6360 - accuracy: 0.6129 - val_loss: 0.9295 - val_accuracy: 0.5425
# Epoch 45/70
# 434/434 [==============================] - 95s 218ms/step - loss: 0.6062 - accuracy: 0.6561 - val_loss: 0.7788 - val_accuracy: 0.5425
# Epoch 46/70
# 434/434 [==============================] - 98s 226ms/step - loss: 0.5881 - accuracy: 0.6889 - val_loss: 0.7512 - val_accuracy: 0.5356
# Epoch 47/70
# 434/434 [==============================] - 101s 234ms/step - loss: 0.5915 - accuracy: 0.6884 - val_loss: 0.7354 - val_accuracy: 0.5425
# Epoch 48/70
# 434/434 [==============================] - 102s 236ms/step - loss: 0.5799 - accuracy: 0.6832 - val_loss: 0.6626 - val_accuracy: 0.5379
# Epoch 49/70
# 434/434 [==============================] - 101s 234ms/step - loss: 0.5754 - accuracy: 0.6941 - val_loss: 0.6684 - val_accuracy: 0.5425
# Epoch 50/70
# 434/434 [==============================] - 100s 231ms/step - loss: 0.5605 - accuracy: 0.6976 - val_loss: 0.6618 - val_accuracy: 0.6115

# %%
loss, accuracy = convlstm_model.evaluate(features_test,labels_test,batch_size=4)
print(f"Test Accuracy:{accuracy*100:.2f}%")
# Out:
# 136/136 [==============================] - 8s 59ms/step - loss: 0.6063 - accuracy: 0.6703
# Test Accuracy:67.03%

# %%
convlstm_model.save("convlstm_model.h5")

# %%
def plot_metric(model_training_history, metric_name_1, metric_name_2, plot_name):
    
    metric_value_1 = model_training_history.history[metric_name_1]
    metric_value_2 = model_training_history.history[metric_name_2]
    
    # Get the Epochs Count
    epochs = range(len(metric_value_1))
 
    plt.plot(epochs, metric_value_1, 'blue', label = metric_name_1)
    plt.plot(epochs, metric_value_2, 'orange', label = metric_name_2)
 
    plt.title(str(plot_name))
 
    plt.legend()

    plt.show()

# %%
plot_metric(convlstm_model_training_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')

# %%
plot_metric(convlstm_model_training_history, 'accuracy', 'val_accuracy', 'Total Loss vs Total Validation Loss')

# %%
labels_predict = convlstm_model.predict(features_test)
# Out:
# 17/17 [==============================] - 3s 98ms/step

# %%
# Decoding the data to use in Metrics
labels_predict = np.argmax(labels_predict , axis=1)
labels_test_normal = np.argmax(labels_test , axis=1)

# %%
labels_test_normal.shape , labels_predict.shape
# Out:
# ((543,), (543,))

# %%
from sklearn.metrics import accuracy_score
AccScore = accuracy_score(labels_predict, labels_test_normal)
print('Accuracy Score is : ', AccScore)
# Out:
# Accuracy Score is :  0.6703499079189686

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\student\.conda\envs\py310\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\student\.conda\envs\py310\lib\site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=1.2 in c:\users\student\.conda\envs\py310\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\student\.conda\envs\py310\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\student\.conda\envs\py310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\student\.conda\envs\py310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\student\.conda\envs\py310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\student\.conda\envs\py310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\student\.conda\envs\py310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\student\.conda\envs\py310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\student\.conda\envs\py310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\student\.conda\envs\py310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\student\.conda\envs\py310\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\student\.conda\envs\py310\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\student\.conda\envs\py310\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
import seaborn as sns 
from sklearn.metrics import confusion_matrix

ax= plt.subplot()
cm=confusion_matrix(labels_test_normal, labels_predict)
sns.heatmap(cm, annot=True, fmt='g', ax=ax);  

ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(['True', 'False']); ax.yaxis.set_ticklabels(['crime', 'non-crime']);

# %%
from sklearn.metrics import classification_report

ClassificationReport = classification_report(labels_test_normal,labels_predict)
print('Classification Report is : \n', ClassificationReport)
# Out:
# Classification Report is :
#                precision    recall  f1-score   support
#
#            0       0.85      0.33      0.48       246
#            1       0.63      0.95      0.76       297
#
#     accuracy                           0.67       543
#    macro avg       0.74      0.64      0.62       543
# weighted avg       0.73      0.67      0.63       543

# %% [markdown]
# ### Prediction

# %%
def predict_video(video_file_path, SEQUENCE_LENGTH):
 
    video_reader = cv2.VideoCapture(video_file_path)
 
    # Get the width and height of the video.
    original_video_width = int(video_reader.get(cv2.CAP_PROP_FRAME_WIDTH))
    original_video_height = int(video_reader.get(cv2.CAP_PROP_FRAME_HEIGHT))
 
    # Declare a list to store video frames we will extract.
    frames_list = []
    
    # Store the predicted class in the video.
    predicted_class_name = ''
 
    # Get the number of frames in the video.
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
 
    # Calculate the interval after which frames will be added to the list.
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH),1)
 
    # Iterating the number of times equal to the fixed length of sequence.
    for frame_counter in range(SEQUENCE_LENGTH):
 
        # Set the current frame position of the video.
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)
 
        success, frame = video_reader.read() 
 
        if not success:
            break
 
        # Resize the Frame to fixed Dimensions.
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))
        
        # Normalize the resized frame.
        normalized_frame = resized_frame / 255
        
        # Appending the pre-processed frame into the frames list
        frames_list.append(normalized_frame)
 
    # Passing the  pre-processed frames to the model and get the predicted probabilities.
    predicted_labels_probabilities = convlstm_model.predict(np.expand_dims(frames_list, axis = 0))[0]
 
    # Get the index of class with highest probability.
    predicted_label = np.argmax(predicted_labels_probabilities)
 
    # Get the class name using the retrieved index.
    predicted_class_name = CLASSES_LIST[predicted_label]
    
    # Display the predicted class along with the prediction confidence.
    print(f'Predicted: {predicted_class_name}\nConfidence: {predicted_labels_probabilities[predicted_label]}')
        
    video_reader.release()

# %%
# Specifying video to be predicted
input_video_file_path = "D:/21102A0004/data/crime/20-V1 (18).mp4"

# Perform Single Prediction on the Test Video.
predict_video(input_video_file_path, SEQUENCE_LENGTH)
# Out:
# 1/1 [==============================] - 0s 194ms/step
# Predicted: crime
# Confidence: 0.5515106916427612
